# %% [markdown]
# # DataFrames
# ### Till now we have worked upon series which is 1-d array of a dataset as we used to extract a column from dataset to work upon.
# ### But Now we will use multi-dimension set of array that is a complete dataframe that will have multiple columns.

# %%
import pandas as pd              #importing the module.

# %%
df = pd.read_csv('Titanic_Data.csv')      #No need of squeeze as we don't want to convert it into series and no need of usecols as we want all the columns.
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()             #Top 5 values by default
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()            #Last 5 values by deafult
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.index             #Range of index starting from and ending.
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.dtypes           #Datatype of each column.
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns            #Gives all the columns in form of an array.
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.axes               #It gives range of the index and columns as well
# Out:
# [RangeIndex(start=0, stop=891, step=1),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
df.info()                 #It gives some info about the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.sum()                           #I adds data of all the rows for each column.
# Out:
# PassengerId                                               397386
# Survived                                                     342
# Pclass                                                      2057
# Name           Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sex            malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                      21205.2
# SibSp                                                        466
# Parch                                                        340
# Ticket         A/5 21171PC 17599STON/O2. 31012821138033734503...
# Fare                                                     28693.9
# dtype: object

# %%
df.sum(axis=1)                    #It adds data of all columns.So it is giving result of each row.
# Out:
# 0       34.2500
# 1      114.2833
# 2       40.9250
# 3       95.1000
# 4       51.0500
#          ...
# 886    929.0000
# 887    939.0000
# 888    918.4500
# 889    948.0000
# 890    933.7500
# Length: 891, dtype: float64

# %%
df.sum(axis="index")              #Work same as df.sum() and adds all rows.It is by deafult value.
# Out:
# PassengerId                                               397386
# Survived                                                     342
# Pclass                                                      2057
# Name           Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sex            malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                      21205.2
# SibSp                                                        466
# Parch                                                        340
# Ticket         A/5 21171PC 17599STON/O2. 31012821138033734503...
# Fare                                                     28693.9
# dtype: object

# %%
df.sum(axis="columns")               #Work same as df.sum(axis=1) and adds all columns.
# Out:
# 0       34.2500
# 1      114.2833
# 2       40.9250
# 3       95.1000
# 4       51.0500
#          ...
# 886    929.0000
# 887    939.0000
# 888    918.4500
# 889    948.0000
# 890    933.7500
# Length: 891, dtype: float64

# %% [markdown]
# ### Note:-
# Sum function has parameter axis and axis=0(same as asix="index") is the default value which adds data of all rows and axis=1(same as axis="columns") adds data of all columns.

# %%
name=df.Name          #To extract any column of the dataset but it will not work if we have a gap in the name of column.
name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(name)          #It is a series type data as we extracted just one column.
# Out:
# pandas.core.series.Series

# %% [markdown]
# # How to extract columns from a dataset

# %%
df["Name"]            #This method to extract a column will work everytime either we have gap in name of column or not.
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[["Name","Sex","Fare"]]              #To extract more than 1 columns.Need to use two square brackets.
# Out:
#                                                   Name     Sex     Fare
# 0                              Braund, Mr. Owen Harris    male   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  71.2833
# 2                               Heikkinen, Miss. Laina  female   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  53.1000
# 4                             Allen, Mr. William Henry    male   8.0500
# ..                                                 ...     ...      ...
# 886                              Montvila, Rev. Juozas    male  13.0000
# 887                       Graham, Miss. Margaret Edith  female  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  23.4500
# 889                              Behr, Mr. Karl Howell    male  30.0000
# 890                                Dooley, Mr. Patrick    male   7.7500
#
# [891 rows x 3 columns]

# %%
cols = ["Name","Sex","Fare"]               #It gives the same result and is more efficient way to extract columns.
df[cols]
# Out:
#                                                   Name     Sex     Fare
# 0                              Braund, Mr. Owen Harris    male   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  71.2833
# 2                               Heikkinen, Miss. Laina  female   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  53.1000
# 4                             Allen, Mr. William Henry    male   8.0500
# ..                                                 ...     ...      ...
# 886                              Montvila, Rev. Juozas    male  13.0000
# 887                       Graham, Miss. Margaret Edith  female  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  23.4500
# 889                              Behr, Mr. Karl Howell    male  30.0000
# 890                                Dooley, Mr. Patrick    male   7.7500
#
# [891 rows x 3 columns]

# %%
df["Name"][0]            #To extract a particular row of any column.
# Out:
# 'Braund, Mr. Owen Harris'

# %% [markdown]
# # How to insert columns in a dataset

# %%
df["New"]="New Column"       #To add a new column."New" is the name of new column and "New Column" is the value to be added in that.
df.head()                    #As we can see "New" column has been added in the end.Can only be used to add columnb in end.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked         New
# 0      0         A/5 21171   7.2500   NaN        S  New Column
# 1      0          PC 17599  71.2833   C85        C  New Column
# 2      0  STON/O2. 3101282   7.9250   NaN        S  New Column
# ...

# %%
df.insert(3,column="Crash",value="Yes")         #3 parameters need to passed here.First is index, 2nd is name of column to be added and 3rd in value to be added in that column.
 #Remember not to run this function twice as this column has been already added and running again will give an error that column already exists.

# %%
df.head()                   #This method is used to insert a new column at our desired place instead of ending.
# Out:
#    PassengerId  Survived  Pclass Crash  \
# 0            1         0       3   Yes
# 1            2         1       1   Yes
# 2            3         1       3   Yes
# 3            4         1       1   Yes
# 4            5         0       3   Yes
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked         New
# 0      0         A/5 21171   7.2500   NaN        S  New Column
# 1      0          PC 17599  71.2833   C85        C  New Column
# 2      0  STON/O2. 3101282   7.9250   NaN        S  New Column
# ...

# %%
df.insert(5,"Sea","Great")               #We can also write name of columns and values directly.

# %%
df.head()                   #New column "Sea" has been added at 5th index.
# Out:
#    PassengerId  Survived  Pclass Crash  \
# 0            1         0       3   Yes
# 1            2         1       1   Yes
# 2            3         1       3   Yes
# 3            4         1       1   Yes
# 4            5         0       3   Yes
#
#                                                 Name    Sea     Sex   Age  \
# 0                            Braund, Mr. Owen Harris  Great    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Great  female  38.0
# 2                             Heikkinen, Miss. Laina  Great  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Great  female  35.0
# 4                           Allen, Mr. William Henry  Great    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked         New
# 0      1      0         A/5 21171   7.2500   NaN        S  New Column
# 1      1      0          PC 17599  71.2833   C85        C  New Column
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  New Column
# ...

# %% [markdown]
# # How to remove a column from a dataset
# ### drop function is used to remove a particular column from dataset. 3 paraemeters need to be passed here :-
# #### 1.Name of the column which we need to drop.
# #### 2.axis=1 , it takes axis=0 by default which is used for row as we disscussed earlier.So axis=1 is very important otherwise it will assume axis to be 0 and will show an error as the column name will not be found in rows.
# #### 3.inplace=True , it is very important as it makes permanent changes in dataset.If we don't pass this parameter then column will be dropped temporarily and if we will do further operations then this operation will be erased and column will be showed in dataset.

# %%
df.drop("Crash",axis=1,inplace=True)      #Dropped Crash column which we added recently.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name    Sea     Sex   Age  \
# 0                            Braund, Mr. Owen Harris  Great    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Great  female  38.0
# 2                             Heikkinen, Miss. Laina  Great  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Great  female  35.0
# 4                           Allen, Mr. William Henry  Great    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked         New
# 0      1      0         A/5 21171   7.2500   NaN        S  New Column
# 1      1      0          PC 17599  71.2833   C85        C  New Column
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  New Column
# ...

# %%
df.drop(["New","Sea"],axis=1,inplace=True)          #To drop multiple columns at once.
#Remember not to run drop  function twice as it will give an error that column does not exist as it has been dropped already.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Binary Operations on columns
# ### To make an operation on the whole series or column.

# %%
df["Age"].add(5)             #5 is added to each row in the column "age".
# Out:
# 0      27.0
# 1      43.0
# 2      31.0
# 3      40.0
# 4      40.0
#        ...
# 886    32.0
# 887    24.0
# 888     NaN
# 889    31.0
# 890    37.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]+5              #Same work can be done by this without using add operator.
# Out:
# 0      27.0
# 1      43.0
# 2      31.0
# 3      40.0
# 4      40.0
#        ...
# 886    32.0
# 887    24.0
# 888     NaN
# 889    31.0
# 890    37.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].sub(2)            #To subsract 2 from each row of column "Age".
# Out:
# 0      20.0
# 1      36.0
# 2      24.0
# 3      33.0
# 4      33.0
#        ...
# 886    25.0
# 887    17.0
# 888     NaN
# 889    24.0
# 890    30.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]-4                  #Same substarction can be done by this method without using sub operator.
# Out:
# 0      18.0
# 1      34.0
# 2      22.0
# 3      31.0
# 4      31.0
#        ...
# 886    23.0
# 887    15.0
# 888     NaN
# 889    22.0
# 890    28.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].mul(3)           #To multiply each row of columnn "age" with 3.
# Out:
# 0       66.0
# 1      114.0
# 2       78.0
# 3      105.0
# 4      105.0
#        ...
# 886     81.0
# 887     57.0
# 888      NaN
# 889     78.0
# 890     96.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]*2              #Same multiplication can be done by this way also.
# Out:
# 0      44.0
# 1      76.0
# 2      52.0
# 3      70.0
# 4      70.0
#        ...
# 886    54.0
# 887    38.0
# 888     NaN
# 889    52.0
# 890    64.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].div(4)          #To divide each row of columnn "age" with 4.
# Out:
# 0      5.50
# 1      9.50
# 2      6.50
# 3      8.75
# 4      8.75
#        ...
# 886    6.75
# 887    4.75
# 888     NaN
# 889    6.50
# 890    8.00
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]/4              #Same divison can be done by this way also.
# Out:
# 0      5.50
# 1      9.50
# 2      6.50
# 3      8.75
# 4      8.75
#        ...
# 886    6.75
# 887    4.75
# 888     NaN
# 889    6.50
# 890    8.00
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]//2            #Similarily we can apply all the binary operations on the whole column.
# Out:
# 0      11.0
# 1      19.0
# 2      13.0
# 3      17.0
# 4      17.0
#        ...
# 886    13.0
# 887     9.0
# 888     NaN
# 889    13.0
# 890    16.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]%3
# Out:
# 0      1.0
# 1      2.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 886    0.0
# 887    1.0
# 888    NaN
# 889    2.0
# 890    2.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age after 10 years"] = df["Age"]+10           #To perform binary operation on a column and adding it to a new column.

# %%
df[7,"Age after 10 years"] = df["Age"]+10

# %%
df.head()                #Added new column "Age after 10 years" by adding value of "Age" column by 10.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age after 10 years  \
# 0      0         A/5 21171   7.2500   NaN        S                32.0
# 1      0          PC 17599  71.2833   C85        C                48.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S                36.0
# ...

# %% [markdown]
# # Null values
# ### In our dataset , we might have null values and they can be shown as NaN or blank spaces.We need to fill them or drop them if a row is completely null before starting working on dataset.
# ### How to drop null values.
# #### 'dropna' method is used to drop null values.

# %%
df1 = pd.read_csv('fatal-police-shootings-data.csv')    #Importing new dataset.
df1
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
df1.dropna(inplace=True)                  #It will drop all the rows which have null values.You can check that rows have been reduced from 5416 to 4399.
     #Inplace is required to save these changes permanantlyWe can also check other parameters of dropna by shift + TAB button.

# %%
df1.dropna(how="any")     #how is an arguement that is passed in dropna method.Any will do the same work that is deleting all rows which have any null values.
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 5408  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 5409  5925      Caine Van Pelt  2020-06-12              shot         gun
# 5410  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 5411  5921      William Slyter  2020-06-13              shot         gun
# 5413  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender race           city state  signs_of_mental_illness  \
# ...

# %%
df1.dropna(how="all",inplace=True)     #how="all" will drop only those rows whose all values are null.This dataset doesn't have any row which has all null values.So still it has 5416 rows.
df1
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
df1.dropna(axis=1)     #To drop the columns having null null values.axis = 0 is the default value which is for row.
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 5408  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 5409  5925      Caine Van Pelt  2020-06-12              shot         gun
# 5410  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 5411  5921      William Slyter  2020-06-13              shot         gun
# 5413  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender race           city state  signs_of_mental_illness  \
# ...

# %% [markdown]
# ### How to fill null values
# #### fillna method is used to fill null values.

# %%
df1          #As you can see we have dropped all rows with null values permanantly by using inplace=True so we need to import data again.
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 5408  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 5409  5925      Caine Van Pelt  2020-06-12              shot         gun
# 5410  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 5411  5921      William Slyter  2020-06-13              shot         gun
# 5413  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender race           city state  signs_of_mental_illness  \
# ...

# %%
df2 = pd.read_csv('fatal-police-shootings-data.csv') 
df2          #Now again we have our otiginal dataset with null or missing values.
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
df2["age"].fillna(0,inplace=True)     #To fill value of "Age" column only with 0.
df2             #You can check alos row no.5412 has NaN for 'age' and now it has 0.
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
df2["race"].fillna("W",inplace=True)           #We can fill any particular column with value of our choice.
                                 #"race" column had NaN for 5412th row and now it has 'W' which we filled
df2
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
df2.tail()
# Out:
#         id            name        date manner_of_death         armed   age  \
# 5411  5921  William Slyter  2020-06-13            shot           gun  22.0
# 5412  5922           TK TK  2020-06-13            shot  undetermined   0.0
# 5413  5924  Nicholas Hirsh  2020-06-15            shot           gun  31.0
# 5414  5926           TK TK  2020-06-16            shot           gun  24.0
# 5415  5927           TK TK  2020-06-16            shot           gun  27.0
#
#      gender race            city state  signs_of_mental_illness threat_level  \
# 5411      M    W     Kansas City    MO                    False        other
# 5412      M    W  San Bernardino    CA                    False       attack
# 5413      M    W        Lawrence    KS                    False       attack
# 5414      M    W      Beach Park    IL                    False       attack
# 5415      M    W         Phoenix    AZ                    False       attack
#
#              flee  body_camera
# ...

# %% [markdown]
# #### Now the best way to fill null values is by filling it with mean of whole column.Doing it for age column as it has integer values.
# #### We need to load the dataset again as we had set null values of 'age' as 0 permanantly using inplace=True

# %%
df3 = pd.read_csv('fatal-police-shootings-data.csv')
df3.tail()         #Now as you can see we again have NaN values in 'age' column.
# Out:
#         id            name        date manner_of_death         armed   age  \
# 5411  5921  William Slyter  2020-06-13            shot           gun  22.0
# 5412  5922           TK TK  2020-06-13            shot  undetermined   NaN
# 5413  5924  Nicholas Hirsh  2020-06-15            shot           gun  31.0
# 5414  5926           TK TK  2020-06-16            shot           gun  24.0
# 5415  5927           TK TK  2020-06-16            shot           gun  27.0
#
#      gender race            city state  signs_of_mental_illness threat_level  \
# 5411      M    W     Kansas City    MO                    False        other
# 5412      M  NaN  San Bernardino    CA                    False       attack
# 5413      M    W        Lawrence    KS                    False       attack
# 5414      M  NaN      Beach Park    IL                    False       attack
# 5415      M  NaN         Phoenix    AZ                    False       attack
#
#              flee  body_camera
# ...

# %%
df3["age"].mean()         #Mean of 'age' column
# Out:
# 37.11793090137039

# %%
df3.fillna(df3["age"].mean())        #Filling null values with mean of 'age' column.
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
#             age gender     race            city state  \
# ...

# %% [markdown]
# ## Sorting Values in DataFrames

# %%
df3.sort_values("name")        #Sorting a column "name" in ascending order(A-Z).By default , it has ascending=True.
# Out:
#         id                    name        date manner_of_death  \
# 689    820   Austin Wilburly  Reid  2015-09-10            shot
# 134    176      A'Donte Washington  2015-02-23            shot
# 4918  5316               A.B. Carr  2019-12-28            shot
# 4047  4451     Aaron Allen Przekop  2019-02-08            shot
# 2442  2717            Aaron Bailey  2017-06-29            shot
# ...    ...                     ...         ...             ...
# 2464  2927           Zepp Crouchet  2017-07-04            shot
# 1939  2166             Zhonghua Li  2016-12-24            shot
# 2891  3213             Zoe Dowdell  2017-12-14            shot
# 3944  4367         Zonell Williams  2019-01-04            shot
# 5220  5734       Zyon Romeir Wyche  2020-04-09            shot
#
#                armed   age gender race              city state  \
# 689              gun  32.0      M    W              Lodi    CA
# 134              gun  16.0      M    B         Millbrook    AL
# ...

# %%
df3.sort_values("name",ascending=False)      #To sort values in descending order(Z-A).Putting ascending=False.
# Out:
#         id                    name        date manner_of_death  \
# 5220  5734       Zyon Romeir Wyche  2020-04-09            shot
# 3944  4367         Zonell Williams  2019-01-04            shot
# 2891  3213             Zoe Dowdell  2017-12-14            shot
# 1939  2166             Zhonghua Li  2016-12-24            shot
# 2464  2927           Zepp Crouchet  2017-07-04            shot
# ...    ...                     ...         ...             ...
# 2442  2717            Aaron Bailey  2017-06-29            shot
# 4047  4451     Aaron Allen Przekop  2019-02-08            shot
# 4918  5316               A.B. Carr  2019-12-28            shot
# 134    176      A'Donte Washington  2015-02-23            shot
# 689    820   Austin Wilburly  Reid  2015-09-10            shot
#
#                armed   age gender race              city state  \
# 5220             gun  19.0      M    B  Colonial Heights    VA
# 3944             gun  33.0      M    B             Treme    LA
# ...

# %%
df3.sort_values("age")      #All the null values are kept in the end after the sorting of the columnas you can see in 'age'column.
# Out:
#         id              name        date   manner_of_death         armed  \
# 833    980     Jeremy Mardis  2015-11-03              shot       unarmed
# 2908  3229  Kameron Prescott  2017-12-21              shot       unarmed
# 1017  1165       Ciara Meyer  2016-01-11              shot       unarmed
# 1681  1883         Tyre King  2016-09-14              shot    toy weapon
# 3985  4386      Antonio Arce  2019-01-15              shot    toy weapon
# ...    ...               ...         ...               ...           ...
# 5373  5880             TK TK  2020-05-28              shot       crowbar
# 5375  5851             TK TK  2020-05-28  shot and Tasered         knife
# 5377  5845             TK TK  2020-05-29              shot    toy weapon
# 5379  5849             TK TK  2020-05-29              shot         knife
# 5412  5922             TK TK  2020-06-13              shot  undetermined
#
#        age gender race               city state  signs_of_mental_illness  \
# ...

# %%
df3.sort_values(["name","age"])    #To sort multiple columns.Here sorting will be done wrt to first column and other columns will be sorted according to first one.
#Here it is sorted with 'name' column as it is given first and 'age' is sorted later according to 'name' column.
# Out:
#         id                    name        date manner_of_death  \
# 689    820   Austin Wilburly  Reid  2015-09-10            shot
# 134    176      A'Donte Washington  2015-02-23            shot
# 4918  5316               A.B. Carr  2019-12-28            shot
# 4047  4451     Aaron Allen Przekop  2019-02-08            shot
# 2442  2717            Aaron Bailey  2017-06-29            shot
# ...    ...                     ...         ...             ...
# 2464  2927           Zepp Crouchet  2017-07-04            shot
# 1939  2166             Zhonghua Li  2016-12-24            shot
# 2891  3213             Zoe Dowdell  2017-12-14            shot
# 3944  4367         Zonell Williams  2019-01-04            shot
# 5220  5734       Zyon Romeir Wyche  2020-04-09            shot
#
#                armed   age gender race              city state  \
# 689              gun  32.0      M    W              Lodi    CA
# 134              gun  16.0      M    B         Millbrook    AL
# ...

# %%
df3.sort_values(["age","name"]) #Here sorting is done wrt to 'age' column first and then wrt to 'name' column.
# Out:
#         id              name        date manner_of_death       armed   age  \
# 833    980     Jeremy Mardis  2015-11-03            shot     unarmed   6.0
# 2908  3229  Kameron Prescott  2017-12-21            shot     unarmed   6.0
# 1017  1165       Ciara Meyer  2016-01-11            shot     unarmed  12.0
# 1681  1883         Tyre King  2016-09-14            shot  toy weapon  13.0
# 3985  4386      Antonio Arce  2019-01-15            shot  toy weapon  14.0
# ...    ...               ...         ...             ...         ...   ...
# 1388  1581             Tk Tk  2016-05-26            shot       knife   NaN
# 1486  1673      Tyrone Reado  2016-06-29            shot         gun   NaN
# 4545  4959      Uzzle Jerome  2019-08-17            shot         gun   NaN
# 1472  1664  William Ferguson  2016-06-25            shot         gun   NaN
# 4195  4617    Zachary Kinard  2019-04-03            shot         gun   NaN
#
# ...

# %%
df3.sort_values(["age","name"],ascending=[True,False])    #If we want to sort both the columns in different orders. First in ascending order and the second in descending order.
# Out:
#         id                name        date   manner_of_death       armed  \
# 2908  3229    Kameron Prescott  2017-12-21              shot     unarmed
# 833    980       Jeremy Mardis  2015-11-03              shot     unarmed
# 1017  1165         Ciara Meyer  2016-01-11              shot     unarmed
# 1681  1883           Tyre King  2016-09-14              shot  toy weapon
# 1588  1776  Jesse James Romero  2016-08-09              shot         gun
# ...    ...                 ...         ...               ...         ...
# 1463  1649        Angelo Brown  2016-06-23              shot         gun
# 3132  3462    Angel Luis Ortiz  2018-03-04              shot  toy weapon
# 1831  2037      Andrew Depeiza  2016-11-11  shot and Tasered     unarmed
# 127    584   Alejandro Salazar  2015-02-20              shot         gun
# 3915  4327       Abdias Flores  2018-12-24              shot         gun
#
#        age gender race               city state  signs_of_mental_illness  \
# ...

# %% [markdown]
# # Rank method

# %%
df3.dropna()        #Dropping all the null values.
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 5408  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 5409  5925      Caine Van Pelt  2020-06-12              shot         gun
# 5410  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 5411  5921      William Slyter  2020-06-13              shot         gun
# 5413  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender race           city state  signs_of_mental_illness  \
# ...

# %%
df3["age"].fillna(0,inplace=True)           #Filling null values by 0 permanantly.
df3["age"].astype(int)               #Setting the type of column 'age' as interger.
# Out:
# 0       53
# 1       47
# 2       23
# 3       32
# 4       39
#         ..
# 5411    22
# 5412     0
# 5413    31
# 5414    24
# 5415    27
# Name: age, Length: 5416, dtype: int32

# %%
df3["age"].rank().astype(int)
# Out:
# 0       4717
# 1       4246
# 2        887
# 3       2363
# 4       3438
#         ...
# 5411     764
# 5412     118
# 5413    2186
# 5414    1031
# 5415    1528
# Name: age, Length: 5416, dtype: int32

# %%
df3["age rank"] = df3["age"].rank(ascending=True).astype(int)      #We have added a new column with name 'age rank' in the end which has ranked values of 'age' in ascedning order.
df3
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
# ...

# %%
df3.sort_values(by="age",ascending=True)           #Now we have sorted values of 'age' in ascedning order and 'age rank' column is showing it's rank.
# Out:
#         id               name        date   manner_of_death    armed   age  \
# 3969  4522              TK TK  2019-01-11  shot and Tasered       ax   0.0
# 1929  2154              TK TK  2016-12-21              shot    knife   0.0
# 4347  4773        Ryan Twyman  2019-06-06              shot  unarmed   0.0
# 4344  4765           Jay Clem  2019-06-05              shot      gun   0.0
# 4761  5151              TK TK  2019-11-04              shot      gun   0.0
# ...    ...                ...         ...               ...      ...   ...
# 3740  4100       Kay Kenniker  2018-10-12              shot      gun  84.0
# 426    542  Raymond  Phillips  2015-06-11              shot      gun  86.0
# 1678  1880       Eugene Craig  2016-09-12              shot      gun  86.0
# 3313  4264    James D. Warren  2018-04-25              shot      gun  89.0
# 2162  2407    Frank W. Wratny  2017-03-08              shot      gun  91.0
#
# ...

# %% [markdown]
# # Filtering Dataset

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5416 entries, 0 to 5415
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       5416 non-null   int64
#  1   name                     5416 non-null   object
#  2   date                     5416 non-null   object
#  3   manner_of_death          5416 non-null   object
#  4   armed                    5189 non-null   object
#  5   age                      5416 non-null   float64
#  6   gender                   5414 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     5416 non-null   object
#  9   state                    5416 non-null   object
#  10  signs_of_mental_illness  5416 non-null   bool
#  11  threat_level             5416 non-null   object
#  12  flee                     5167 non-null   object
#  13  body_camera              5416 non-null   bool
# ...

# %%
df3["date"].head()     #It is a datetime type of data.But it is being shown here as an object which is string.
# Out:
# 0    2015-01-02
# 1    2015-01-02
# 2    2015-01-03
# 3    2015-01-04
# 4    2015-01-04
# Name: date, dtype: object

# %%
pd.to_datetime(df3["date"])      #Now it's datatype has been changes to datetime.
# Out:
# 0      2015-01-02
# 1      2015-01-02
# 2      2015-01-03
# 3      2015-01-04
# 4      2015-01-04
#           ...
# 5411   2020-06-13
# 5412   2020-06-13
# 5413   2020-06-15
# 5414   2020-06-16
# 5415   2020-06-16
# Name: date, Length: 5416, dtype: datetime64[ns]

# %%
df3["age"].head()      #It is also a float data but age should be in integer.
# Out:
# 0    53.0
# 1    47.0
# 2    23.0
# 3    32.0
# 4    39.0
# Name: age, dtype: float64

# %%
df3["age"].astype(int).head()           #It has been changed to integer type.
# Out:
# 0    53
# 1    47
# 2    23
# 3    32
# 4    39
# Name: age, dtype: int32

# %%
df3["flee"] == "Not fleeing"      #Now we are comparing values of a column 'flee'.If the value is same as given condition then it returns true otherwise False.
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5411    False
# 5412     True
# 5413    False
# 5414     True
# 5415     True
# Name: flee, Length: 5416, dtype: bool

# %%
#Now to extract only values which we want.Put it inside one more df.
df3[df3["flee"] == "Not fleeing"]
#Now it have given us only those rows which has balue 'not fleeing' in column 'flee'.
# Out:
#         id                name       date   manner_of_death         armed  \
# 0        3          Tim Elliot 2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke 2015-01-02              shot           gun
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman 2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez 2015-01-04              shot      nail gun
# ...    ...                 ...        ...               ...           ...
# 5407  5915      Michael Thomas 2020-06-11              shot  undetermined
# 5410  5918        Hannah Fizer 2020-06-13              shot       unarmed
# 5412  5922               TK TK 2020-06-13              shot  undetermined
# 5414  5926               TK TK 2020-06-16              shot           gun
# 5415  5927               TK TK 2020-06-16              shot           gun
#
#        age gender race            city state  signs_of_mental_illness  \
# ...

# %%
df3[df3["manner_of_death"]=="shot"]    #Now we have only those rows which have value 'shot' for column 'manner_of_death'.
# Out:
#         id               name       date manner_of_death         armed   age  \
# 0        3         Tim Elliot 2015-01-02            shot           gun  53.0
# 1        4   Lewis Lee Lembke 2015-01-02            shot           gun  47.0
# 3        8    Matthew Hoffman 2015-01-04            shot    toy weapon  32.0
# 4        9  Michael Rodriguez 2015-01-04            shot      nail gun  39.0
# 5       11  Kenneth Joe Brown 2015-01-04            shot           gun  18.0
# ...    ...                ...        ...             ...           ...   ...
# 5411  5921     William Slyter 2020-06-13            shot           gun  22.0
# 5412  5922              TK TK 2020-06-13            shot  undetermined   NaN
# 5413  5924     Nicholas Hirsh 2020-06-15            shot           gun  31.0
# 5414  5926              TK TK 2020-06-16            shot           gun  24.0
# 5415  5927              TK TK 2020-06-16            shot           gun  27.0
#
# ...

# %%
df3["state"]!="CA"     #This is a condition of not equal to.It will return those rows which does not have these values.
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 5411     True
# 5412    False
# 5413     True
# 5414     True
# 5415     True
# Name: state, Length: 5416, dtype: bool

# %%
df3[df3["state"]!="CA"]        #Now we have only those rows whose 'state' column does not have 'CA' value.
# Out:
#         id                name       date   manner_of_death     armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot       gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot       gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered   unarmed  23.0
# 4        9   Michael Rodriguez 2015-01-04              shot  nail gun  39.0
# 5       11   Kenneth Joe Brown 2015-01-04              shot       gun  18.0
# ...    ...                 ...        ...               ...       ...   ...
# 5410  5918        Hannah Fizer 2020-06-13              shot   unarmed  25.0
# 5411  5921      William Slyter 2020-06-13              shot       gun  22.0
# 5413  5924      Nicholas Hirsh 2020-06-15              shot       gun  31.0
# 5414  5926               TK TK 2020-06-16              shot       gun  24.0
# 5415  5927               TK TK 2020-06-16              shot       gun  27.0
#
# ...

# %%
df3[df3["signs_of_mental_illness"]]    #If we have a column which already has data in boolean form then we don't need to write whole condition.We can write only this and it will return True values.
# Out:
#         id                            name       date manner_of_death  \
# 0        3                      Tim Elliot 2015-01-02            shot
# 3        8                 Matthew Hoffman 2015-01-04            shot
# 12      22  Hashim Hanif Ibn Abdul-Rasheed 2015-01-07            shot
# 21      42                     Tommy Smith 2015-01-11            shot
# 25      48               Richard McClendon 2015-01-13            shot
# ...    ...                             ...        ...             ...
# 5357  5860                 Kenneth Bennett 2020-05-26            shot
# 5376  5844           Heba Momtaz Al-Azhari 2020-05-29            shot
# 5400  5908                    Jarrid Hurst 2020-06-07            shot
# 5401  5909                 Michael Seltzer 2020-06-08            shot
# 5406  5914                Mason James Lira 2020-06-11            shot
#
#            armed   age gender race            city state  \
# 0            gun  53.0      M    A         Shelton    WA
# ...

# %%
df3["armed"].isin(["knife","gun"])         #isin() method is used to apply condition for multiple values.To get both values 'knife' and 'gun' for column 'armed'.
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 5411     True
# 5412    False
# 5413     True
# 5414     True
# 5415     True
# Name: armed, Length: 5416, dtype: bool

# %%
life = df3["armed"].isin(["knife","gun"])      #Put this into a variable life.
df3[life]       #Now it will show only those rows which have values either 'knife' or 'gun'.
# Out:
#         id                 name       date manner_of_death armed   age gender  \
# 0        3           Tim Elliot 2015-01-02            shot   gun  53.0      M
# 1        4     Lewis Lee Lembke 2015-01-02            shot   gun  47.0      M
# 5       11    Kenneth Joe Brown 2015-01-04            shot   gun  18.0      M
# 6       13  Kenneth Arnold Buck 2015-01-05            shot   gun  22.0      M
# 7       15        Brock Nichols 2015-01-06            shot   gun  35.0      M
# ...    ...                  ...        ...             ...   ...   ...    ...
# 5409  5925       Caine Van Pelt 2020-06-12            shot   gun  23.0      M
# 5411  5921       William Slyter 2020-06-13            shot   gun  22.0      M
# 5413  5924       Nicholas Hirsh 2020-06-15            shot   gun  31.0      M
# 5414  5926                TK TK 2020-06-16            shot   gun  24.0      M
# 5415  5927                TK TK 2020-06-16            shot   gun  27.0      M
#
# ...

# %%
race = df3["race"].isin(["A","H"])        #Applying isin() method on 'race' column.
df3[race]        #Will show only those rows which have 'A' or 'H' values for column 'race'.
# Out:
#         id                 name       date   manner_of_death         armed  \
# 0        3           Tim Elliot 2015-01-02              shot           gun
# 2        5   John Paul Quintero 2015-01-03  shot and Tasered       unarmed
# 4        9    Michael Rodriguez 2015-01-04              shot      nail gun
# 6       13  Kenneth Arnold Buck 2015-01-05              shot           gun
# 20     325        Andy Martinez 2015-01-09              shot           gun
# ...    ...                  ...        ...               ...           ...
# 5378  5848                TK TK 2020-05-29              shot           gun
# 5386  5866          Jorge Gomez 2020-06-01              shot           gun
# 5389  5896      Sean Monterrosa 2020-06-02              shot        hammer
# 5393  5904       Eric A. Galvan 2020-06-03              shot           gun
# 5397  5900         Erik Salgado 2020-06-06              shot  undetermined
#
# ...

# %%
null = df3["race"].isnull()     #isnull() method is used to extract all the null values of a column.
df3[null]              #Here we can see that 521 rows has null values for column 'race' which have been extracted.
# Out:
#         id                  name       date   manner_of_death         armed  \
# 59     110      William Campbell 2015-01-25              shot           gun
# 240    244    John Marcell Allen 2015-03-30              shot           gun
# 270    534            Mark Smith 2015-04-09  shot and Tasered           NaN
# 340    433            Joseph Roy 2015-05-07              shot         knife
# 398    503  James Anthony Morris 2015-05-31              shot           gun
# ...    ...                   ...        ...               ...           ...
# 5402  5910    Marcus James Uribe 2020-06-09              shot           gun
# 5404  5912       Jerry M. Bethel 2020-06-10              shot           gun
# 5412  5922                 TK TK 2020-06-13              shot  undetermined
# 5414  5926                 TK TK 2020-06-16              shot           gun
# 5415  5927                 TK TK 2020-06-16              shot           gun
#
# ...

# %%
age = df3["age"].notnull()     #notnull() method is used to get all the values except null values.
df3[age]
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 5410  5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 5411  5921      William Slyter 2020-06-13              shot         gun  22.0
# 5413  5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
# 5414  5926               TK TK 2020-06-16              shot         gun  24.0
# 5415  5927               TK TK 2020-06-16              shot         gun  27.0
#
# ...

# %%
df3["age"].between(32,47)       #To get values between a start and end values.It will return only True or False based upon condition.
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 5411    False
# 5412    False
# 5413    False
# 5414    False
# 5415    False
# Name: age, Length: 5416, dtype: bool

# %%
age = df3["age"].between(34,56)       #Only those rows are extracted whose age is between 34 and 56.
df3[age]
# Out:
#         id                   name       date manner_of_death         armed  \
# 0        3             Tim Elliot 2015-01-02            shot           gun
# 1        4       Lewis Lee Lembke 2015-01-02            shot           gun
# 4        9      Michael Rodriguez 2015-01-04            shot      nail gun
# 7       15          Brock Nichols 2015-01-06            shot           gun
# 8       16          Autumn Steele 2015-01-06            shot       unarmed
# ...    ...                    ...        ...             ...           ...
# 5394  5905  Scott Anderson Hutton 2020-06-03            shot  undetermined
# 5395  5903       Benjamin Ballard 2020-06-05            shot           gun
# 5398  5901    Gregory Lee Turnure 2020-06-06            shot    metal pipe
# 5400  5908           Jarrid Hurst 2020-06-07            shot         knife
# 5403  5911           Lewis Ruffin 2020-06-09            shot           gun
#
#        age gender race        city state  signs_of_mental_illness  \
# ...

# %%
date = df3["date"].between("2016-05-20","2019-05-20")     #between method can also be applied on datetime dataype.
df3[date]              #To get the values between two dates.
# Out:
#         id                          name       date manner_of_death    armed  \
# 1369  1559                 Joshua Beebee 2016-05-20            shot    knife
# 1370  1552               Norman Campbell 2016-05-21            shot      gun
# 1371  1553                  Travis Moore 2016-05-21            shot  unarmed
# 1372  1556                   Mark Nelson 2016-05-21            shot      gun
# 1373  1554     Michael Eugene Wilson Jr. 2016-05-22            shot  unarmed
# ...    ...                           ...        ...             ...      ...
# 4302  4742               Ronnie Churches 2019-05-19            shot      gun
# 4303  5419           Lawrence Lee Lovato 2019-05-19            shot      gun
# 4304  4723            Michael Ann Godsey 2019-05-20            shot      gun
# 4305  4724  Carlos Javier Roman Santiago 2019-05-20            shot    knife
# 4306  4726              Enosa Strickland 2019-05-20            shot    knife
#
# ...

# %%
dup_age = df3["age"].duplicated()   #Only first occuerence of a value will be considered original and all others to be duplicate.
df3[dup_age]                    #It has given all the duplicate values which are occuring more than once.
# Out:
#         id                 name       date manner_of_death         armed  \
# 9       17      Leslie Sapp III 2015-01-06            shot    toy weapon
# 21      42          Tommy Smith 2015-01-11            shot           gun
# 22      43       Brian  Barbosa 2015-01-11            shot           gun
# 24      46  John Edward O'Keefe 2015-01-13            shot           gun
# 27      50       Michael Goebel 2015-01-14            shot           NaN
# ...    ...                  ...        ...             ...           ...
# 5411  5921       William Slyter 2020-06-13            shot           gun
# 5412  5922                TK TK 2020-06-13            shot  undetermined
# 5413  5924       Nicholas Hirsh 2020-06-15            shot           gun
# 5414  5926                TK TK 2020-06-16            shot           gun
# 5415  5927                TK TK 2020-06-16            shot           gun
#
#        age gender race             city state  signs_of_mental_illness  \
# ...

# %%
df3["age"].duplicated(keep="last")        #Keep parameter is used.It will consider last occuerence of a value to be original and all other to be duplicate.
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5411    False
# 5412    False
# 5413    False
# 5414    False
# 5415    False
# Name: age, Length: 5416, dtype: bool

# %%
dup = df3["age"].duplicated(keep="last")
df3[dup]
# Out:
#         id                name       date   manner_of_death         armed  \
# 0        3          Tim Elliot 2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke 2015-01-02              shot           gun
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman 2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez 2015-01-04              shot      nail gun
# ...    ...                 ...        ...               ...           ...
# 5396  5899       Kamal Flowers 2020-06-06              shot           gun
# 5397  5900        Erik Salgado 2020-06-06              shot  undetermined
# 5399  5907     Jeffrey McClure 2020-06-07              shot    pellet gun
# 5402  5910  Marcus James Uribe 2020-06-09              shot           gun
# 5408  5916     Rayshard Brooks 2020-06-12              shot         Taser
#
#        age gender race            city state  signs_of_mental_illness  \
# ...

# %%
df3["manner_of_death"].duplicated(keep=False)     #It will only keep the duplicated values.
df3[dupl]
# Out:
#         id                name       date   manner_of_death         armed  \
# 0        3          Tim Elliot 2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke 2015-01-02              shot           gun
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman 2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez 2015-01-04              shot      nail gun
# ...    ...                 ...        ...               ...           ...
# 5411  5921      William Slyter 2020-06-13              shot           gun
# 5412  5922               TK TK 2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh 2020-06-15              shot           gun
# 5414  5926               TK TK 2020-06-16              shot           gun
# 5415  5927               TK TK 2020-06-16              shot           gun
#
#        age gender race            city state  signs_of_mental_illness  \
# ...

# %% [markdown]
# #### drop_duplicates() method is used to drop duplicate values but it will drop a complete row and only when all values of both columns are identical.If only 1 or 2 values are same then it will not consider them to be identical.

# %%
df3.drop_duplicates(subset=["age"],keep="first")   #subet is the parameter used to give the name of column.now after dropping duplicate values for 'age' , we are left with just 78 rows.
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 2269  2524       Robert Becker 2017-04-24              shot         gun  79.0
# 3067  3402       John Hamilton 2018-02-09              shot         gun  78.0
# 3075  3403      Raymond Bishop 2018-02-12              shot         gun  84.0
# 3246  3578      Robert Litolff 2018-04-05              shot         gun  81.0
# 3313  4264     James D. Warren 2018-04-25              shot         gun  89.0
#
# ...

# %%
df3.drop_duplicates(["armed"],"last")      #We don't need to write the name of paramter , we can just write their value.
# Out:
#         id                name       date   manner_of_death            armed  \
# 4        9   Michael Rodriguez 2015-01-04              shot         nail gun
# 432    548        Deng Manyoun 2015-06-13              shot         flagpole
# 447    556   Charles  Marshall 2015-06-21              shot   cordless drill
# 526    642      Anthonie Smith 2015-07-16  shot and Tasered  metal hand tool
# 632    764  Jason Lee Alderman 2015-08-22              shot          carjack
# ...    ...                 ...        ...               ...              ...
# 5400  5908        Jarrid Hurst 2020-06-07              shot            knife
# 5408  5916     Rayshard Brooks 2020-06-12              shot            Taser
# 5410  5918        Hannah Fizer 2020-06-13              shot          unarmed
# 5412  5922               TK TK 2020-06-13              shot     undetermined
# 5415  5927               TK TK 2020-06-16              shot              gun
#
# ...

# %% [markdown]
# # Important :- To know about the parameters of a method , you can use shift+TAB button when the cursor is in the square brackets of the method like shown in the images below.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
df3.drop_duplicates(["age","manner_of_death"])    #To drop from multiple columns.Drop columns whose value of both of these column are same.
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 3075  3403      Raymond Bishop 2018-02-12              shot         gun  84.0
# 3246  3578      Robert Litolff 2018-04-05              shot         gun  81.0
# 3313  4264     James D. Warren 2018-04-25              shot         gun  89.0
# 3327  3656       Vigil Wolford 2018-04-30  shot and Tasered       knife  59.0
# 3752  4129    James Lyle Kuehn 2018-10-17  shot and Tasered       knife  61.0
#
# ...

# %% [markdown]
# # Reset Index

# %%
data = pd.read_csv('fatal-police-shootings-data.csv',index_col="age")      #We have disscussed this method earlier.
data.head()          #Assigning a column as index by 'index_col' parameter while importing the data.
# Out:
#       id                name        date   manner_of_death       armed gender  \
# age
# 53.0   3          Tim Elliot  2015-01-02              shot         gun      M
# 47.0   4    Lewis Lee Lembke  2015-01-02              shot         gun      M
# 23.0   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed      M
# 32.0   8     Matthew Hoffman  2015-01-04              shot  toy weapon      M
# 39.0   9   Michael Rodriguez  2015-01-04              shot    nail gun      M
#
#      race           city state  signs_of_mental_illness threat_level  \
# age
# 53.0    A        Shelton    WA                     True       attack
# 47.0    W          Aloha    OR                    False       attack
# 23.0    H        Wichita    KS                    False        other
# 32.0    W  San Francisco    CA                     True       attack
# 39.0    H          Evans    CO                    False       attack
#
#              flee  body_camera
# age
# 53.0  Not fleeing        False
# ...

# %%
df4 =  pd.read_csv('fatal-police-shootings-data.csv')
df4.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
df4.set_index("city")           #The second method that we can use is set_index after importing the data.Always use inplace=True if you want to save the chnages permanantly.
# Out:
#                   id                name        date   manner_of_death  \
# city
# Shelton            3          Tim Elliot  2015-01-02              shot
# Aloha              4    Lewis Lee Lembke  2015-01-02              shot
# Wichita            5  John Paul Quintero  2015-01-03  shot and Tasered
# San Francisco      8     Matthew Hoffman  2015-01-04              shot
# Evans              9   Michael Rodriguez  2015-01-04              shot
# ...              ...                 ...         ...               ...
# Kansas City     5921      William Slyter  2020-06-13              shot
# San Bernardino  5922               TK TK  2020-06-13              shot
# Lawrence        5924      Nicholas Hirsh  2020-06-15              shot
# Beach Park      5926               TK TK  2020-06-16              shot
# Phoenix         5927               TK TK  2020-06-16              shot
#
#                        armed   age gender race state  signs_of_mental_illness  \
# city
# ...

# %%
df4.head()       #Now here 'city' is no longer an index because I did not apply inplace parameter as True.
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
df4.set_index("age",inplace=True)      #Now we have passes inplace=True so save it permanantly.

# %%
df4.head()                #Now the column 'age' has been set as index.
# Out:
#       id                name        date   manner_of_death       armed gender  \
# age
# 53.0   3          Tim Elliot  2015-01-02              shot         gun      M
# 47.0   4    Lewis Lee Lembke  2015-01-02              shot         gun      M
# 23.0   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed      M
# 32.0   8     Matthew Hoffman  2015-01-04              shot  toy weapon      M
# 39.0   9   Michael Rodriguez  2015-01-04              shot    nail gun      M
#
#      race           city state  signs_of_mental_illness threat_level  \
# age
# 53.0    A        Shelton    WA                     True       attack
# 47.0    W          Aloha    OR                    False       attack
# 23.0    H        Wichita    KS                    False        other
# 32.0    W  San Francisco    CA                     True       attack
# 39.0    H          Evans    CO                    False       attack
#
#              flee  body_camera
# age
# 53.0  Not fleeing        False
# ...

# %%
df4.reset_index(inplace=True)      #Now to reset index(i.e removing 'age' from index) we use reset_index.

# %%
df4.head()     #Now 'age' has been removed from index.
# Out:
#     age  id                name        date   manner_of_death       armed  \
# 0  53.0   3          Tim Elliot  2015-01-02              shot         gun
# 1  47.0   4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2  23.0   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3  32.0   8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4  39.0   9   Michael Rodriguez  2015-01-04              shot    nail gun
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
df4.set_index("race",inplace=True)   #We have set 'race' as the index.

# %%
df4.reset_index(drop=True)         #Now drop parameter will drop the index and setting it's value as True will remove 'race' from index as well as from dataset.SSS
# Out:
#        age    id                name        date   manner_of_death  \
# 0     53.0     3          Tim Elliot  2015-01-02              shot
# 1     47.0     4    Lewis Lee Lembke  2015-01-02              shot
# 2     23.0     5  John Paul Quintero  2015-01-03  shot and Tasered
# 3     32.0     8     Matthew Hoffman  2015-01-04              shot
# 4     39.0     9   Michael Rodriguez  2015-01-04              shot
# ...    ...   ...                 ...         ...               ...
# 5411  22.0  5921      William Slyter  2020-06-13              shot
# 5412   NaN  5922               TK TK  2020-06-13              shot
# 5413  31.0  5924      Nicholas Hirsh  2020-06-15              shot
# 5414  24.0  5926               TK TK  2020-06-16              shot
# 5415  27.0  5927               TK TK  2020-06-16              shot
#
#              armed gender            city state  signs_of_mental_illness  \
# 0              gun      M         Shelton    WA                     True
# ...
